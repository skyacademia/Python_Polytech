# %%
import requests
import json
import datetime

vilage_weather_url = "http://apis.data.go.kr/1360000/VilageFcstInfoService_2.0/getVilageFcst?"

service_key = "PEawh1fJV%2F6OnMG6wuhX0Aptr0KRM8mumNFZdHB8Sv%2FTP4JC00POYkQTrrLDMi6kPp%2BZjXh46SCPb81o84PW9g%3D%3D"
base_date = datetime.datetime.today().strftime("%Y%m%d") # 예) 20220518
base_time = "0800"
nx = "55"
ny = "123"
payload = "serviceKey="+service_key+"&"+"dataType=json"+"&"+"base_date="+base_date+"&"+"base_time="+base_time+"&"+"nx="+nx+"&"+"ny="+ny

res = requests.get(vilage_weather_url+payload)
try:
    items = res.json().get('response').get('body').get('items')
    print(items)
except:
    print("날씨 정보 요청 실패 : ",res.text)
# Out:
# {'item': [{'baseDate': '20220518', 'baseTime': '0800', 'category': 'TMP', 'fcstDate': '20220518', 'fcstTime': '0900', 'fcstValue': '21', 'nx': 55, 'ny': 123}, {'baseDate': '20220518', 'baseTime': '0800', 'category': 'UUU', 'fcstDate': '20220518', 'fcstTime': '0900', 'fcstValue': '-0.3', 'nx': 55, 'ny': 123}, {'baseDate': '20220518', 'baseTime': '0800', 'category': 'VVV', 'fcstDate': '20220518', 'fcstTime': '0900', 'fcstValue': '6.8', 'nx': 55, 'ny': 123}, {'baseDate': '20220518', 'baseTime': '0800', 'category': 'VEC', 'fcstDate': '20220518', 'fcstTime': '0900', 'fcstValue': '177', 'nx': 55, 'ny': 123}, {'baseDate': '20220518', 'baseTime': '0800', 'category': 'WSD', 'fcstDate': '20220518', 'fcstTime': '0900', 'fcstValue': '6.8', 'nx': 55, 'ny': 123}, {'baseDate': '20220518', 'baseTime': '0800', 'category': 'SKY', 'fcstDate': '20220518', 'fcstTime': '0900', 'fcstValue': '4', 'nx': 55, 'ny': 123}, {'baseDate': '20220518', 'baseTime': '0800', 'category': 'PTY', 'fcstDate': '20220518', 'fcstTime': '0900', 'fcstValue': '0', 'nx': 55, 'ny': 123}, {'baseDate': '20220518', 'baseTime': '0800', 'category': 'POP', 'fcstDate': '20220518', 'fcstTime': '0900', 'fcstValue': '30', 'nx': 55, 'ny': 123}, {'baseDate': '20220518', 'baseTime': '0800', 'category': 'WAV', 'fcstDate': '20220518', 'fcstTime': '0900', 'fcstValue': '0', 'nx': 55, 'ny': 123}, {'baseDate': '20220518', 'baseTime': '0800', 'category': 'PCP', 'fcstDate': '20220518', 'fcstTime': '0900', 'fcstValue': '강수없음', 'nx': 55, 'ny': 123}]}

# %%
dust_url = "http://apis.data.go.kr/B552584/ArpltnInforInqireSvc/getCtprvnRltmMesureDnsty?"

service_key = "PEawh1fJV%2F6OnMG6wuhX0Aptr0KRM8mumNFZdHB8Sv%2FTP4JC00POYkQTrrLDMi6kPp%2BZjXh46SCPb81o84PW9g%3D%3D"
base_date = datetime.datetime.today().strftime("%Y%m%d") # 예) 20220518
payload2 = "serviceKey="+service_key+"&"+"returnType=json"+"&"+"sidoName=인천"+"&"+"ver=1.0"

res = requests.get(dust_url+payload2)
result = res.json()
dust = dict()
if ((res.status_code==200)&(result['response']['header']['resultCode']=='00')):
    dust['PM10'] = {'value':int(result['response']['body']['items'][0]['pm10Value'])}
    dust['PM2.5'] = {'value':int(result['response']['body']['items'][0]['pm25Value'])}
else :
    print("미세먼지 가져오기 실패 : ", result['response']['header']['resultMsg'])
print(dust)

# %%
import requests
import json
import datetime
import random
import os

# 카카오
url = "https://kauth.kakao.com/oauth/token"

data={"grant_type":"authorization_code", "client_id":"a1d0272c22893537afb8754e8c60924d","redirect_uri":"https://localhost.com",
"code":"rsrfCX0AOqvr26JK4g7XRSoXqld2-TIShUe4gE5Ck_dZyr8aGhalUgnwPnPamk_PxMq4VQorDKgAAAGA1R5Xfg"}

response = requests.post(url,data=data)
if response.status_code != 200: # 실패
    print("에러 발생했습니다. 이유 : ",response.json())
else: # 성공
    token = response.json()
    print(token)

KAKAO_TOKEN_FILENAME = "C:/Users/super/Desktop/2B_donghoon/2_Python/class/3_pandas_webscraping/kakao/kakao_token.json"

def save_tokens(filename, tokens):
    with open(filename, "w") as fp:
        json.dump(tokens,fp)
save_tokens(KAKAO_TOKEN_FILENAME, token)
KAKAO_TOKEN_FILENAME = "C:/Users/super/Desktop/2B_donghoon/2_Python/class/3_pandas_webscraping/kakao/kakao_token.json"

def save_tokens(filename, tokens):
    with open(filename, "w") as fp:
        json.dump(tokens,fp)

def load_tokens(filename):
    with open(filename) as fp:
        tokens=json.load(fp)
    return tokens

def update_tokens(app_key,filename):
    tokens=load_tokens(filename)

    url = "https://kauth.kakao.com/oauth/token"
    data={
        "grant_type":"refresh_token", "client_id":app_key, "refresh_token" : tokens['refresh_token']
    }
    response = requests.post(url,data=data)

    if response.status_code != 200:
        print("에러발생! 이유 : ", response.json())
        tokens=None
    else:
        print(response.json())
        now = datetime.datetime.now().strftime("%Y%m%d_%H%M%S")
        backup_filename = filename+"."+now
        os.rename(filename, backup_filename)
        tokens['access_token'] = response.json()['access_token']
        save_tokens(filename,tokens)
    return tokens

# save_tokens(KAKAO_TOKEN_FILENAME,tokens)

KAKAO_APP_KEY = "a1d0272c22893537afb8754e8c60924d"
tokens=update_tokens(KAKAO_APP_KEY, KAKAO_TOKEN_FILENAME)
save_tokens(KAKAO_TOKEN_FILENAME,tokens)
# Out:
# {'access_token': 'C3yqteQlOdYUkjMhfPnhL5fuAXQOUsEwBkrQKwo9dJkAAAGA1SX-2g', 'token_type': 'bearer', 'refresh_token': 'SDGIqeqYS3PStk-S6Ajhn6Lg0HHOTnKDJ0YNngo9dJkAAAGA1SX-2A', 'expires_in': 21599, 'scope': 'account_email profile_image talk_message profile_nickname', 'refresh_token_expires_in': 5183999}
# {'access_token': '7VpIkQClxozKyopmqXRgUOzE9bX8mpfIVTGkSQo9dZsAAAGA1SX_PA', 'token_type': 'bearer', 'expires_in': 21599}

# %%
import requests
import json
import datetime
import random

vilage_weather_url = "http://apis.data.go.kr/1360000/VilageFcstInfoService_2.0/getVilageFcst?"

service_key = "PEawh1fJV%2F6OnMG6wuhX0Aptr0KRM8mumNFZdHB8Sv%2FTP4JC00POYkQTrrLDMi6kPp%2BZjXh46SCPb81o84PW9g%3D%3D"
base_date = datetime.datetime.today().strftime("%Y%m%d") # 예) 20220518
base_time = "0800"
nx = "55"
ny = "123"
payload = "serviceKey="+service_key+"&"+"dataType=json"+"&"+"base_date="+base_date+"&"+"base_time="+base_time+"&"+"nx="+nx+"&"+"ny="+ny

pty_code = {"0":"없음","1":"비","2":"비/눈","3":"눈","4":"소나기","5":"빗방울","6":"빗방울/눈날림","7":"눈날림"}

data = dict()
data['data'] = base_date
weather = dict()

res = requests.get(vilage_weather_url+payload)
try:
    items = res.json().get('response').get('body').get('items')
    for item in items['item']:
        if item['category']=="TMP":
            weather['tmp'] = item['fcstValue']
        
        if item['category']=="PTY":
            weather['code'] = item['fcstValue']
            weather['state'] = pty_code[item['fcstValue']]
except:
    print("날씨 정보 요청 실패 : ",res.text)
data['weather'] = weather
print(data['weather'])


def get_pm10_state(pm10_value):
    if pm10_value<30:
        pm10_state = "좋음"
    elif pm10_value<80:
        pm10_state = "보통"
    elif pm10_value<150:
        pm10_state = "나쁨"
    else:
        pm10_state = "매우 나쁨"
    return pm10_state

def get_pm25_state(pm25_value):
    if pm25_value<30:
        pm25_state = "좋음"
    elif pm25_value<80:
        pm25_state = "보통"
    elif pm25_value<150:
        pm25_state = "나쁨"
    else:
        pm25_state = "매우 나쁨"
    return pm25_state


dust_url = "http://apis.data.go.kr/B552584/ArpltnInforInqireSvc/getCtprvnRltmMesureDnsty?"

service_key = "PEawh1fJV%2F6OnMG6wuhX0Aptr0KRM8mumNFZdHB8Sv%2FTP4JC00POYkQTrrLDMi6kPp%2BZjXh46SCPb81o84PW9g%3D%3D"
base_date = datetime.datetime.today().strftime("%Y%m%d") # 예) 20220518
payload2 = "serviceKey="+service_key+"&"+"returnType=json"+"&"+"sidoName=인천"+"&"+"ver=1.0"

res = requests.get(dust_url+payload2)
result = res.json()
dust = dict()
if ((res.status_code==200)&(result['response']['header']['resultCode']=='00')):
    dust['PM10'] = {'value':int(result['response']['body']['items'][0]['pm10Value'])}
    dust['PM2.5'] = {'value':int(result['response']['body']['items'][0]['pm25Value'])}

    pm10_value = dust.get('PM10').get('value')
    pm10_state = get_pm10_state(pm10_value)
    pm25_value = dust.get('PM2.5').get('value')
    pm25_state = get_pm25_state(pm25_value)
    dust.get('PM10')['state'] = pm10_state
    dust.get('PM2.5')['state'] = pm25_state
else :
    print("미세먼지 가져오기 실패 : ", result['response']['header']['resultMsg'])
data['dust'] = dust
print(data['dust'])

rain_foods = "부대찌개,아구찜,해물탕,칼국수,수제비,짬뽕,우동,치킨,국밥,김치부침개,두부김치,파전".split(",")
pmhigh_foods = "콩나물국밥,고등어,굴,쌀국수,마라탕".split(',')

def get_foods_list(weather,dust_pm10,dust_pm25):
    if weather != "0":
        recommand_state = 'Case1'
        foods_list = random.sample(rain_foods,k=len(rain_foods))
    elif dust_pm10=="매우 나쁨" or dust_pm25=="매우 나쁨":
        recommand_state="Case2"
        foods_list=random.sample(pmhigh_foods,k=len(pmhigh_foods))
    else:
        recommand_state="Case3"
        foods_list=['']
    return recommand_state, foods_list

def naver_local_search(query,display):
    headers={"X-Naver-Client-Id":"8W_hkf6fkpUqGBgNgFKX", "X-Naver-Client-Secret":"Y2dXcMEN3j"}
    params={"sort":"comment","query":query,"display":display}
    naver_local_url = "https://openapi.naver.com/v1/search/local.json"
    res=requests.get(naver_local_url,headers=headers,params=params)
    res.raise_for_status()
    info = res.json()
    places = info.get('items')
    return places

weather = data.get('weather').get('code')
dust_pm10 = data.get('dust').get('PM10').get("state")
dust_pm25 = data.get('dust').get('PM2.5').get("state")

weather_state, foods_list = get_foods_list(weather, dust_pm10, dust_pm25)

location = "논현고잔동"
recommands = []
for food in foods_list :
    query = location + " " +food +" 맛집"
    result_list = naver_local_search(query,3)
    if len(result_list)>0:
        if weather_state =="Case3":
            recommands = result_list
            break
        else:
            recommands.append(result_list[0])
    else:
        print("검색 결과 없음")
    if len(recommands)==3:
        break
print(recommands)
# Out:
# {'tmp': '21', 'code': '0', 'state': '없음'}
# {'PM10': {'value': 44, 'state': '보통'}, 'PM2.5': {'value': 26, 'state': '좋음'}}
# [{'title': '무지락설렁탕', 'link': '', 'category': '한식>곰탕,설렁탕', 'description': '', 'telephone': '', 'address': '인천광역시 남동구 고잔동 138-14', 'roadAddress': '인천광역시 남동구 논현고잔로 166', 'mapx': '286514', 'mapy': '533558'}, {'title': '새집손해물칼국수', 'link': 'https://saejipkalguksu.modoo.at', 'category': '한식>칼국수,만두', 'description': '', 'telephone': '', 'address': '인천광역시 남동구 고잔동 633-1', 'roadAddress': '인천광역시 남동구 은청로 9 현태종합상가 에이동 2층 204호 새집해물칼국수', 'mapx': '284595', 'mapy': '534754'}, {'title': '황금장소', 'link': '', 'category': '한식>육류,고기요리', 'description': '', 'telephone': '', 'address': '인천광역시 남동구 고잔동 349-3 2층', 'roadAddress': '인천광역시 남동구 앵고개로 712 2층', 'mapx': '286563', 'mapy': '532587'}]

# %%
"https://search.naver.com/search.naver?where=nexearch&sm=top_hty&fbm=1&ie=utf8&query=%EB%82%A0%EC%94%A8"

text = """
    기온 : {data['weather']['tm2']}
"""
