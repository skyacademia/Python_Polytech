# %%
import requests
from bs4 import BeautifulSoup
import lxml

# %%
url = "https://comic.naver.com/webtoon/weekday"
header = {"User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/100.0.4896.127 Safari/537.36"}
res = requests.get(url,headers=header)
res.raise_for_status()

bs = BeautifulSoup(res.text,"lxml")

# %%
first = bs.find_all("div",attrs={"class":"col"})
# Out:
# <class 'bs4.element.ResultSet'>

# %%
for article in first:
    print(type(article))
    titles = article.find_all("a",attrs={"class":"title"})
    for title in titles : 
        print(title.get_text())
# Out:
# <class 'bs4.element.Tag'>
# 참교육
# 신의 탑
# 뷰티풀 군바리
# 윈드브레이커
# 쇼미더럭키짱!
# 퀘스트지상주의
# 소녀의 세계
# 장씨세가 호위무사
# 백수세끼
# 팔이피플
# 유미의 작가 수칙
# 앵무살수
# 만렙돌파
# 잔불의 기사
# 리턴 투 플레이어
# 똑 닮은 딸
# 요리GO
# 평범한 8반
# 더블클릭
# 히어로메이커
# 칼가는 소녀
# 파운더
# 다시쓰는 연애사
# 아는 여자애
# 결혼생활 그림일기
# 순정말고 순종
# 아마도
# 물어보는 사이
# 경비실에서 안내방송 드립니다
# 미니어처 생활백서
# 꼬리잡기
# 결혼공략
# 황제와의 하룻밤
# 아, 쫌 참으세요 영주님!
# 신군
# 꿈의 기업
# 이별 후 사내 결혼
# 이제야 연애
# 오빠집이 비어서
# 또다시, 계약 부부
# 매지컬 급식
# 제왕: 빛과 그림자
# 파견체
# 말박왕
# 입술이 예쁜 남자
# 야생천사 보호구역
# 싸이코 리벤지
# 사랑의 헌옷수거함
# 바퀴
# 원작은 완결난 지 한참 됐습니다만
# 레지나레나 - 용서받지 못한 그대에게
# 원하는 건 너 하나
# 홍천기
# 최후의 금빛아이
# 왕따협상
# 개밥 먹는 남자
# 찌질하지만 로맨스는 하고 싶어
# 달로 만든 아이
# 모스크바의 여명
# 마지막 지수
# 나만의 고막남친
# 디나운스
# 모락모락 왕세자님
# 그림자 신부
# 백호랑
# 악녀 18세 공략기
# 역주행!
# 헬로맨스
# 사막에 핀 달
# 별을 쫓는 소년들
# 남주서치
# 오로지 오로라
# 중독연구소
# 결백한 사람은 없다
# 슈퍼스타 천대리
# 기사님을 지켜줘
# <class 'bs4.element.Tag'>
# 김부장
# 여신강림
# 대학원 탈출일지
# 쇼미더럭키짱!
# 멸망 이후의 세계
# 1을 줄게
# 내가 키운 S급들
# 한림체육관
# 사신소년
# 중증외상센터 : 골든 아워
# 하루만 네가 되고 싶어
# 용사가 돌아왔다
# 니나의 마법서랍
# 신도림
# 삼국지톡
# 랜덤채팅의 그녀!
# 헬58
# 집이 없어
# 엽총소년
# ...

# %%
url = "https://news.naver.com/main/main.naver?mode=LSD&mid=shm&sid1=100"
header = {"User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/100.0.4896.127 Safari/537.36"}
res = requests.get(url,headers=header)
res.raise_for_status()

bs = BeautifulSoup(res.text,"lxml")

# %%
lists=bs.find_all("div",attrs={"class":"cluster_item"},limit=3)
    for article in lists : 
        print(article.find("a",attrs={"class":"cluster_text_headline nclicks(cls_pol.clsart)"}).get_text())
